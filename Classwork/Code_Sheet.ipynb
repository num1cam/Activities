# %%
import pandas as pd
import numpy as np
import matplotlib as plot
import openpyxl

# %%
df1= pd.read_csv(r'C:\Users\danie\OneDrive\Desktop\SavvyCoders\Activities\Class Project\data\IEA_Global_EV_2030_Projections_Data_2023.csv')
df2= pd.read_excel(r'C:\Users\danie\OneDrive\Desktop\SavvyCoders\Activities\Class Project\data\StatePopulations.xlsx')
df3= pd.read_excel(r'C:\Users\danie\OneDrive\Desktop\SavvyCoders\Activities\Class Project\data\mv-registration-counts-by-state.xlsx')
df4= pd.read_excel(r'C:\Users\danie\OneDrive\Desktop\SavvyCoders\Activities\Class Project\data\ev-registration-counts-by-state_6-30-22(altered).xlsx')
df5= pd.read_csv(r'C:\Users\danie\OneDrive\Desktop\SavvyCoders\Activities\Class Project\data\alt_fuel_stations(Nov-3-2023).csv', low_memory='False')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_40604\1451157987.py:5: DtypeWarning: Columns (6,16,20,25,31,33,36,43,46,52,53,57,58,60,62,65,67,69,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5= pd.read_csv(r'C:\Users\danie\OneDrive\Desktop\SavvyCoders\Activities\Class Project\data\alt_fuel_stations(Nov-3-2023).csv', low_memory='False')

# %%
df4.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#          region        category       parameter    mode powertrain  year  \
# 0     Australia      Historical        EV stock    Cars        BEV  2011
# 1     Australia      Historical  EV sales share    Cars         EV  2011
# 2     Australia      Historical  EV stock share    Cars         EV  2011
# 3     Australia      Historical        EV sales    Cars        BEV  2011
# 4     Australia      Historical        EV sales    Cars        BEV  2012
# ...         ...             ...             ...     ...        ...   ...
# 9537      World  Projection-APS        EV stock  Trucks       PHEV  2030
# 9538      World  Projection-APS        EV stock    Vans        BEV  2030
# 9539      World  Projection-APS        EV stock    Vans       PHEV  2030
# 9540      World  Projection-APS        EV stock    Cars        BEV  2030
# 9541      World  Projection-APS        EV stock    Cars       PHEV  2030
#
#           unit         value
# 0     Vehicles  4.900000e+01
# 1      percent  6.500000e-03
# ...

# %%
df2
# Out:
#                     State   Population
# 0                Alabama     4,817,678
# 1                 Alaska       728,300
# 2                Arizona     6,561,516
# 3               Arkansas     2,947,036
# 4             California    38,066,920
# 5               Colorado     5,197,580
# 6            Connecticut     3,592,053
# 7               Delaware       917,060
# 8   District of Columbia       633,736
# 9                Florida    19,361,792
# 10               Georgia     9,907,756
# 11                Hawaii     1,392,704
# 12                 Idaho     1,599,464
# 13              Illinois    12,868,747
# 14               Indiana     6,542,411
# 15                  Iowa     3,078,116
# 16                Kansas     2,882,946
# 17              Kentucky     4,383,272
# 18             Louisiana     4,601,049
# 19                 Maine     1,328,535
# 20              Maryland     5,887,776
# 21         Massachusetts     6,657,291
# 22              Michigan     9,889,024
# ...

# %%
df3
# Out:
#          State Motor-Vehicle Registrations - 2021 (1)   Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN          NaN        NaN
# 1                  February 2023 (Revised March 2023)          NaN        NaN
# 2                                                 NaN          NaN        NaN
# 3                                                 NaN  AUTOMOBILES        NaN
# 4                                               STATE  PRIVATE AND        NaN
# ..                                                ...          ...        ...
# 61  (1) Published data reflects State-supplied dat...          NaN        NaN
# 62  (2) State did not report government registrati...          NaN        NaN
# 63  (3) Data was estimated by FHWA due to data qua...          NaN        NaN
# 64  (4) State verified significant decreases in re...          NaN        NaN
# 65  (5) State provided estimated registration data...          NaN        NaN
#
# ...

# %%
df4
# Out:
#     Unnamed: 0                               Unnamed: 1          Unnamed: 2  \
# 0          NaN  Electric Vehicle Registrations by State                 NaN
# 1          NaN                                    State  Registration Count
# 2          NaN                                  Alabama                4750
# 3          NaN                                   Alaska                1290
# 4          NaN                                  Arizona               40740
# 5          NaN                                 Arkansas                2390
# 6          NaN                               California              563070
# 7          NaN                                 Colorado               37000
# 8          NaN                              Connecticut               13350
# 9          NaN                                 Delaware                3010
# 10         NaN                     District of Columbia                3700
# ...

# %%
df1.query("category == 'Projection-STEPS' or category == 'Projection-APS'")
# Out:
#      region          category           parameter    mode  \
# 1331  China  Projection-STEPS  EV charging points      EV
# 1332  China  Projection-STEPS  EV charging points      EV
# 1335  China  Projection-STEPS            EV sales   Buses
# 1336  China  Projection-STEPS            EV stock   Buses
# 1337  China  Projection-STEPS            EV sales   Buses
# ...     ...               ...                 ...     ...
# 9537  World    Projection-APS            EV stock  Trucks
# 9538  World    Projection-APS            EV stock    Vans
# 9539  World    Projection-APS            EV stock    Vans
# 9540  World    Projection-APS            EV stock    Cars
# 9541  World    Projection-APS            EV stock    Cars
#
#                    powertrain  year             unit        value
# 1331  Publicly available fast  2020  charging points     310000.0
# 1332  Publicly available slow  2020  charging points     500000.0
# 1335                      BEV  2020         Vehicles      62000.0
# ...

# %%
df1_invest = df1[['region', 'value']]
df1_invest.query("region == 'USA' or region == 'rest of the world'")
# Out:
#      region       value
# 8376    USA     0.00016
# 8377    USA     9.20000
# 8378    USA    96.00000
# 8379    USA   480.00000
# 8380    USA  3800.00000
# ...     ...         ...
# 8715    USA     4.00000
# 8716    USA    50.00000
# 8717    USA    28.00000
# 8718    USA    13.00000
# 8719    USA    16.00000
#
# [344 rows x 2 columns]
